# %% [markdown]
# <a href="https://colab.research.google.com/github/officialaryansingh/C-programming-basics/blob/main/vehicle_telemetry_data_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import queue
import threading
import time
import random

# %%
# 1. DATA STRUCTURE: Using a thread-safe Queue to stream telemetry data
telemetry_queue = queue.Queue(maxsize=10)
